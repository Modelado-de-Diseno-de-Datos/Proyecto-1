# %% [markdown]
# ## Carga de Datos

# %%
import pandas as pd

import os
import numpy as np
import pandas as pd
from sklearn import tree
import sklearn as sklearn

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D # for 3D plots
import seaborn as sns; sns.set()

df_kaggle = pd.read_csv("vgsales.csv")
print(df_kaggle.head())
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
import os, time, math, requests, pandas as pd
from pandas import json_normalize

API_KEY = "601b475a2c3342c1860c7f432da840ca"          # <-- pon tu key
TARGET_N = 17000                # apunta un poco arriba de 16k por pérdidas al limpiar
PAGE_SIZE = 40                  # máximo permitido por RAWG
SLEEP_BASE = 0.8                # espera entre llamadas (ajústalo si ves 429)
OUT_EVERY = 1000                # guarda en disco cada N filas
OUT_CSV = "rawg_games_raw.csv"  # salida incremental
FINAL_CSV = "rawg_games_clean.csv"

def fetch_page(page: int, ordering="-added", dates=None):
    """
    ordering: ver docs RAWG; '-added' o '-rating' suelen devolver populares primero.
    dates: '2000-01-01,2025-12-31' para acotar (opcional).
    """
    params = {
        "key": API_KEY,
        "page": page,
        "page_size": PAGE_SIZE,
        "ordering": ordering
    }
    if dates:
        params["dates"] = dates

    # reintentos simples con backoff si hay 429/5xx
    for attempt in range(6):
        r = requests.get("https://api.rawg.io/api/games", params=params, timeout=30)
        if r.status_code == 200:
            return r.json()
        if r.status_code in (429, 500, 502, 503, 504):
            wait = SLEEP_BASE * (2 ** attempt)
            time.sleep(wait)
        else:
            r.raise_for_status()
    raise RuntimeError(f"Fallo permanente en página {page}: {r.status_code} {r.text[:200]}")

# --- Descarga paginada con guardado incremental ---
all_rows = []
seen_ids = set()
total_fetched = 0
page = 1

# Si ya existe un CSV previo, retoma desde ahí
if os.path.exists(OUT_CSV):
    prev = pd.read_csv(OUT_CSV)
    seen_ids = set(prev["id"].tolist())
    total_fetched = len(prev)
    print(f"Retomando: {total_fetched} filas ya guardadas.")
    all_rows = prev.to_dict(orient="records")

while total_fetched < TARGET_N:
    data = fetch_page(page, ordering="-added")   # puedes usar también "-rating" o "-metacritic"
    results = data.get("results", [])
    if not results:
        print("No hay más resultados (next=None).")
        break

    # filtra duplicados por id
    new = [row for row in results if row["id"] not in seen_ids]
    for row in new:
        seen_ids.add(row["id"])
        all_rows.append(row)

    total_fetched = len(all_rows)
    print(f"Página {page} | nuevos={len(new)} | total={total_fetched}")

    # guardado incremental
    if total_fetched % OUT_EVERY < PAGE_SIZE:  # aprox cada OUT_EVERY
        pd.DataFrame(all_rows).to_csv(OUT_CSV, index=False)
        print(f"Guardado parcial -> {OUT_CSV}")

    page += 1
    time.sleep(SLEEP_BASE)  # cortesía para no saturar

# guardado final crudo
pd.DataFrame(all_rows).to_csv(OUT_CSV, index=False)
print(f"Descarga cruda completa: {len(all_rows)} filas -> {OUT_CSV}")

# --- Normalización y limpieza (aplanar columnas útiles) ---
df = pd.read_csv(OUT_CSV)

# json_normalize maneja listas/dict si cargamos desde objetos; si cargaste desde csv,
# vuelve a leer desde 'all_rows' o re-normaliza antes de guardar. Aquí rehacemos:
df_norm = json_normalize(all_rows, max_level=1)

# columnas derivadas legibles
def join_list(objs, path_names):
    if isinstance(objs, list):
        try:
            if path_names == "platforms":
                return ", ".join(o["platform"]["name"] for o in objs)
            if path_names == "genres":
                return ", ".join(o["name"] for o in objs)
            if path_names == "stores":
                return ", ".join(o["store"]["name"] for o in objs)
        except Exception:
            return None
    return None

df_norm["platforms_names"] = df_norm["platforms"].apply(lambda x: join_list(x, "platforms"))
df_norm["genres_names"]     = df_norm["genres"].apply(lambda x: join_list(x, "genres"))
df_norm["stores_names"]     = df_norm["stores"].apply(lambda x: join_list(x, "stores"))

# selecciona columnas clave
cols = [
    "id","slug","name","released","rating","ratings_count","metacritic","playtime",
    "added","suggestions_count","updated","platforms_names","genres_names","stores_names",
    "background_image","esrb_rating.name"
]
cols = [c for c in cols if c in df_norm.columns]
df_rawg = df_norm[cols].copy()

# elimina duplicados (por id y por nombre por si acaso)
df_rawg = df_rawg.drop_duplicates(subset=["id"])
df_rawg = df_rawg.drop_duplicates(subset=["name"])  # opcional

# guarda limpio
df_rawg.to_csv(FINAL_CSV, index=False)
print(f"Limpio listo: {len(df_rawg)} filas -> {FINAL_CSV}")
# Out:
# Página 1 | nuevos=40 | total=40
# Página 2 | nuevos=40 | total=80
# Página 3 | nuevos=40 | total=120
# Página 4 | nuevos=40 | total=160
# Página 5 | nuevos=40 | total=200
# Página 6 | nuevos=40 | total=240
# Página 7 | nuevos=40 | total=280
# Página 8 | nuevos=40 | total=320
# Página 9 | nuevos=40 | total=360
# Página 10 | nuevos=40 | total=400
# Página 11 | nuevos=40 | total=440
# Página 12 | nuevos=40 | total=480
# Página 13 | nuevos=40 | total=520
# Página 14 | nuevos=40 | total=560
# Página 15 | nuevos=40 | total=600
# Página 16 | nuevos=40 | total=640
# Página 17 | nuevos=40 | total=680
# Página 18 | nuevos=40 | total=720
# Página 19 | nuevos=40 | total=760
# Página 20 | nuevos=40 | total=800
# Página 21 | nuevos=40 | total=840
# Página 22 | nuevos=40 | total=880
# Página 23 | nuevos=40 | total=920
# Página 24 | nuevos=40 | total=960
# Página 25 | nuevos=40 | total=1000
# Guardado parcial -> rawg_games_raw.csv
# Página 26 | nuevos=40 | total=1040
# Página 27 | nuevos=40 | total=1080
# Página 28 | nuevos=40 | total=1120
# Página 29 | nuevos=40 | total=1160
# Página 30 | nuevos=40 | total=1200
# Página 31 | nuevos=40 | total=1240
# Página 32 | nuevos=40 | total=1280
# Página 33 | nuevos=40 | total=1320
# Página 34 | nuevos=40 | total=1360
# Página 35 | nuevos=40 | total=1400
# Página 36 | nuevos=40 | total=1440
# Página 37 | nuevos=40 | total=1480
# Página 38 | nuevos=40 | total=1520
# Página 39 | nuevos=40 | total=1560
# Página 40 | nuevos=40 | total=1600
# Página 41 | nuevos=40 | total=1640
# Página 42 | nuevos=40 | total=1680
# Página 43 | nuevos=40 | total=1720
# Página 44 | nuevos=40 | total=1760
# Página 45 | nuevos=40 | total=1800
# Página 46 | nuevos=40 | total=1840
# Página 47 | nuevos=40 | total=1880
# Página 48 | nuevos=40 | total=1920
# Página 49 | nuevos=40 | total=1960
# Página 50 | nuevos=40 | total=2000
# Guardado parcial -> rawg_games_raw.csv
# Página 51 | nuevos=40 | total=2040
# Página 52 | nuevos=40 | total=2080
# Página 53 | nuevos=40 | total=2120
# Página 54 | nuevos=40 | total=2160
# Página 55 | nuevos=40 | total=2200
# Página 56 | nuevos=40 | total=2240
# Página 57 | nuevos=40 | total=2280
# Página 58 | nuevos=40 | total=2320
# Página 59 | nuevos=40 | total=2360
# Página 60 | nuevos=40 | total=2400
# Página 61 | nuevos=40 | total=2440
# Página 62 | nuevos=40 | total=2480
# Página 63 | nuevos=40 | total=2520
# Página 64 | nuevos=40 | total=2560
# Página 65 | nuevos=40 | total=2600
# Página 66 | nuevos=40 | total=2640
# Página 67 | nuevos=40 | total=2680
# Página 68 | nuevos=40 | total=2720
# Página 69 | nuevos=40 | total=2760
# Página 70 | nuevos=40 | total=2800
# Página 71 | nuevos=40 | total=2840
# Página 72 | nuevos=40 | total=2880
# Página 73 | nuevos=40 | total=2920
# Página 74 | nuevos=40 | total=2960
# Página 75 | nuevos=40 | total=3000
# Guardado parcial -> rawg_games_raw.csv
# Página 76 | nuevos=40 | total=3040
# Página 77 | nuevos=40 | total=3080
# Página 78 | nuevos=40 | total=3120
# Página 79 | nuevos=40 | total=3160
# Página 80 | nuevos=40 | total=3200
# Página 81 | nuevos=40 | total=3240
# Página 82 | nuevos=40 | total=3280
# Página 83 | nuevos=40 | total=3320
# Página 84 | nuevos=40 | total=3360
# Página 85 | nuevos=40 | total=3400
# Página 86 | nuevos=40 | total=3440
# Página 87 | nuevos=40 | total=3480
# Página 88 | nuevos=40 | total=3520
# Página 89 | nuevos=40 | total=3560
# Página 90 | nuevos=40 | total=3600
# Página 91 | nuevos=40 | total=3640
# Página 92 | nuevos=40 | total=3680
# Página 93 | nuevos=40 | total=3720
# Página 94 | nuevos=40 | total=3760
# Página 95 | nuevos=40 | total=3800
# Página 96 | nuevos=40 | total=3840
# Página 97 | nuevos=40 | total=3880
# Página 98 | nuevos=40 | total=3920
# Página 99 | nuevos=40 | total=3960
# Página 100 | nuevos=40 | total=4000
# Guardado parcial -> rawg_games_raw.csv
# Página 101 | nuevos=40 | total=4040
# Página 102 | nuevos=40 | total=4080
# Página 103 | nuevos=40 | total=4120
# Página 104 | nuevos=40 | total=4160
# Página 105 | nuevos=40 | total=4200
# Página 106 | nuevos=40 | total=4240
# Página 107 | nuevos=40 | total=4280
# Página 108 | nuevos=40 | total=4320
# Página 109 | nuevos=40 | total=4360
# Página 110 | nuevos=40 | total=4400
# Página 111 | nuevos=40 | total=4440
# Página 112 | nuevos=40 | total=4480
# Página 113 | nuevos=40 | total=4520
# Página 114 | nuevos=40 | total=4560
# Página 115 | nuevos=40 | total=4600
# Página 116 | nuevos=40 | total=4640
# Página 117 | nuevos=40 | total=4680
# Página 118 | nuevos=40 | total=4720
# Página 119 | nuevos=40 | total=4760
# Página 120 | nuevos=40 | total=4800
# Página 121 | nuevos=40 | total=4840
# Página 122 | nuevos=40 | total=4880
# Página 123 | nuevos=40 | total=4920
# Página 124 | nuevos=40 | total=4960
# Página 125 | nuevos=40 | total=5000
# Guardado parcial -> rawg_games_raw.csv
# Página 126 | nuevos=40 | total=5040
# Página 127 | nuevos=40 | total=5080
# Página 128 | nuevos=40 | total=5120
# Página 129 | nuevos=40 | total=5160
# Página 130 | nuevos=40 | total=5200
# Página 131 | nuevos=40 | total=5240
# Página 132 | nuevos=40 | total=5280
# Página 133 | nuevos=40 | total=5320
# Página 134 | nuevos=40 | total=5360
# Página 135 | nuevos=40 | total=5400
# Página 136 | nuevos=40 | total=5440
# Página 137 | nuevos=40 | total=5480
# Página 138 | nuevos=40 | total=5520
# Página 139 | nuevos=40 | total=5560
# Página 140 | nuevos=40 | total=5600
# Página 141 | nuevos=40 | total=5640
# Página 142 | nuevos=40 | total=5680
# Página 143 | nuevos=40 | total=5720
# Página 144 | nuevos=40 | total=5760
# Página 145 | nuevos=40 | total=5800
# Página 146 | nuevos=40 | total=5840
# Página 147 | nuevos=40 | total=5880
# Página 148 | nuevos=40 | total=5920
# Página 149 | nuevos=40 | total=5960
# Página 150 | nuevos=40 | total=6000
# Guardado parcial -> rawg_games_raw.csv
# Página 151 | nuevos=40 | total=6040
# Página 152 | nuevos=40 | total=6080
# Página 153 | nuevos=40 | total=6120
# Página 154 | nuevos=40 | total=6160
# Página 155 | nuevos=40 | total=6200
# Página 156 | nuevos=40 | total=6240
# Página 157 | nuevos=40 | total=6280
# Página 158 | nuevos=40 | total=6320
# Página 159 | nuevos=40 | total=6360
# Página 160 | nuevos=40 | total=6400
# Página 161 | nuevos=40 | total=6440
# Página 162 | nuevos=40 | total=6480
# Página 163 | nuevos=40 | total=6520
# Página 164 | nuevos=40 | total=6560
# Página 165 | nuevos=40 | total=6600
# Página 166 | nuevos=40 | total=6640
# Página 167 | nuevos=40 | total=6680
# Página 168 | nuevos=40 | total=6720
# Página 169 | nuevos=40 | total=6760
# Página 170 | nuevos=40 | total=6800
# Página 171 | nuevos=40 | total=6840
# Página 172 | nuevos=40 | total=6880
# Página 173 | nuevos=40 | total=6920
# Página 174 | nuevos=40 | total=6960
# Página 175 | nuevos=40 | total=7000
# Guardado parcial -> rawg_games_raw.csv
# Página 176 | nuevos=40 | total=7040
# Página 177 | nuevos=40 | total=7080
# Página 178 | nuevos=40 | total=7120
# Página 179 | nuevos=40 | total=7160
# Página 180 | nuevos=40 | total=7200
# Página 181 | nuevos=40 | total=7240
# Página 182 | nuevos=40 | total=7280
# Página 183 | nuevos=40 | total=7320
# Página 184 | nuevos=40 | total=7360
# Página 185 | nuevos=40 | total=7400
# Página 186 | nuevos=40 | total=7440
# Página 187 | nuevos=40 | total=7480
# Página 188 | nuevos=40 | total=7520
# Página 189 | nuevos=40 | total=7560
# Página 190 | nuevos=40 | total=7600
# Página 191 | nuevos=40 | total=7640
# Página 192 | nuevos=40 | total=7680
# Página 193 | nuevos=40 | total=7720
# Página 194 | nuevos=40 | total=7760
# Página 195 | nuevos=40 | total=7800
# Página 196 | nuevos=40 | total=7840
# Página 197 | nuevos=40 | total=7880
# Página 198 | nuevos=40 | total=7920
# Página 199 | nuevos=40 | total=7960
# Página 200 | nuevos=40 | total=8000
# Guardado parcial -> rawg_games_raw.csv
# Página 201 | nuevos=40 | total=8040
# Página 202 | nuevos=40 | total=8080
# Página 203 | nuevos=40 | total=8120
# Página 204 | nuevos=40 | total=8160
# Página 205 | nuevos=40 | total=8200
# Página 206 | nuevos=40 | total=8240
# Página 207 | nuevos=40 | total=8280
# Página 208 | nuevos=40 | total=8320
# Página 209 | nuevos=40 | total=8360
# Página 210 | nuevos=40 | total=8400
# Página 211 | nuevos=40 | total=8440
# Página 212 | nuevos=40 | total=8480
# Página 213 | nuevos=40 | total=8520
# Página 214 | nuevos=40 | total=8560
# Página 215 | nuevos=40 | total=8600
# Página 216 | nuevos=40 | total=8640
# Página 217 | nuevos=40 | total=8680
# Página 218 | nuevos=40 | total=8720
# Página 219 | nuevos=40 | total=8760
# Página 220 | nuevos=40 | total=8800
# Página 221 | nuevos=40 | total=8840
# Página 222 | nuevos=40 | total=8880
# Página 223 | nuevos=40 | total=8920
# Página 224 | nuevos=40 | total=8960
# Página 225 | nuevos=40 | total=9000
# Guardado parcial -> rawg_games_raw.csv
# Página 226 | nuevos=40 | total=9040
# Página 227 | nuevos=40 | total=9080
# Página 228 | nuevos=40 | total=9120
# Página 229 | nuevos=40 | total=9160
# Página 230 | nuevos=40 | total=9200
# Página 231 | nuevos=40 | total=9240
# Página 232 | nuevos=40 | total=9280
# Página 233 | nuevos=40 | total=9320
# Página 234 | nuevos=40 | total=9360
# Página 235 | nuevos=40 | total=9400
# Página 236 | nuevos=40 | total=9440
# Página 237 | nuevos=40 | total=9480
# Página 238 | nuevos=40 | total=9520
# Página 239 | nuevos=40 | total=9560
# Página 240 | nuevos=40 | total=9600
# Página 241 | nuevos=40 | total=9640
# Página 242 | nuevos=40 | total=9680
# Página 243 | nuevos=40 | total=9720
# Página 244 | nuevos=40 | total=9760
# Página 245 | nuevos=40 | total=9800
# Página 246 | nuevos=40 | total=9840
# Página 247 | nuevos=40 | total=9880
# Página 248 | nuevos=40 | total=9920
# Página 249 | nuevos=40 | total=9960
# Página 250 | nuevos=40 | total=10000
# Guardado parcial -> rawg_games_raw.csv
# Página 251 | nuevos=40 | total=10040
# Página 252 | nuevos=40 | total=10080
# Página 253 | nuevos=40 | total=10120
# Página 254 | nuevos=40 | total=10160
# Página 255 | nuevos=40 | total=10200
# Página 256 | nuevos=40 | total=10240
# Página 257 | nuevos=40 | total=10280
# Página 258 | nuevos=40 | total=10320
# Página 259 | nuevos=40 | total=10360
# Página 260 | nuevos=40 | total=10400
# Página 261 | nuevos=40 | total=10440
# Página 262 | nuevos=40 | total=10480
# Página 263 | nuevos=40 | total=10520
# Página 264 | nuevos=40 | total=10560
# Página 265 | nuevos=40 | total=10600
# Página 266 | nuevos=40 | total=10640
# Página 267 | nuevos=40 | total=10680
# Página 268 | nuevos=40 | total=10720
# Página 269 | nuevos=40 | total=10760
# Página 270 | nuevos=40 | total=10800
# Página 271 | nuevos=40 | total=10840
# Página 272 | nuevos=40 | total=10880
# Página 273 | nuevos=40 | total=10920
# Página 274 | nuevos=40 | total=10960
# Página 275 | nuevos=40 | total=11000
# Guardado parcial -> rawg_games_raw.csv
# Página 276 | nuevos=40 | total=11040
# Página 277 | nuevos=40 | total=11080
# Página 278 | nuevos=40 | total=11120
# Página 279 | nuevos=40 | total=11160
# Página 280 | nuevos=40 | total=11200
# Página 281 | nuevos=40 | total=11240
# Página 282 | nuevos=40 | total=11280
# Página 283 | nuevos=40 | total=11320
# Página 284 | nuevos=40 | total=11360
# Página 285 | nuevos=40 | total=11400
# Página 286 | nuevos=40 | total=11440
# Página 287 | nuevos=40 | total=11480
# Página 288 | nuevos=40 | total=11520
# Página 289 | nuevos=40 | total=11560
# Página 290 | nuevos=40 | total=11600
# Página 291 | nuevos=40 | total=11640
# Página 292 | nuevos=40 | total=11680
# Página 293 | nuevos=40 | total=11720
# Página 294 | nuevos=40 | total=11760
# Página 295 | nuevos=40 | total=11800
# Página 296 | nuevos=40 | total=11840
# Página 297 | nuevos=40 | total=11880
# Página 298 | nuevos=40 | total=11920
# Página 299 | nuevos=40 | total=11960
# Página 300 | nuevos=40 | total=12000
# Guardado parcial -> rawg_games_raw.csv
# Página 301 | nuevos=40 | total=12040
# Página 302 | nuevos=40 | total=12080
# Página 303 | nuevos=40 | total=12120
# Página 304 | nuevos=40 | total=12160
# Página 305 | nuevos=40 | total=12200
# Página 306 | nuevos=40 | total=12240
# Página 307 | nuevos=40 | total=12280
# Página 308 | nuevos=40 | total=12320
# Página 309 | nuevos=40 | total=12360
# Página 310 | nuevos=40 | total=12400
# Página 311 | nuevos=40 | total=12440
# Página 312 | nuevos=40 | total=12480
# Página 313 | nuevos=40 | total=12520
# Página 314 | nuevos=40 | total=12560
# Página 315 | nuevos=40 | total=12600
# Página 316 | nuevos=40 | total=12640
# Página 317 | nuevos=40 | total=12680
# Página 318 | nuevos=40 | total=12720
# Página 319 | nuevos=40 | total=12760
# Página 320 | nuevos=40 | total=12800
# Página 321 | nuevos=40 | total=12840
# Página 322 | nuevos=40 | total=12880
# Página 323 | nuevos=40 | total=12920
# Página 324 | nuevos=40 | total=12960
# Página 325 | nuevos=40 | total=13000
# Guardado parcial -> rawg_games_raw.csv
# Página 326 | nuevos=40 | total=13040
# Página 327 | nuevos=40 | total=13080
# Página 328 | nuevos=40 | total=13120
# Página 329 | nuevos=40 | total=13160
# Página 330 | nuevos=40 | total=13200
# Página 331 | nuevos=40 | total=13240
# Página 332 | nuevos=40 | total=13280
# Página 333 | nuevos=40 | total=13320
# Página 334 | nuevos=40 | total=13360
# Página 335 | nuevos=40 | total=13400
# Página 336 | nuevos=40 | total=13440
# Página 337 | nuevos=40 | total=13480
# Página 338 | nuevos=40 | total=13520
# Página 339 | nuevos=40 | total=13560
# Página 340 | nuevos=40 | total=13600
# Página 341 | nuevos=40 | total=13640
# Página 342 | nuevos=40 | total=13680
# Página 343 | nuevos=40 | total=13720
# Página 344 | nuevos=40 | total=13760
# Página 345 | nuevos=40 | total=13800
# Página 346 | nuevos=40 | total=13840
# Página 347 | nuevos=40 | total=13880
# Página 348 | nuevos=40 | total=13920
# Página 349 | nuevos=40 | total=13960
# Página 350 | nuevos=40 | total=14000
# Guardado parcial -> rawg_games_raw.csv
# Página 351 | nuevos=40 | total=14040
# Página 352 | nuevos=40 | total=14080
# Página 353 | nuevos=40 | total=14120
# Página 354 | nuevos=40 | total=14160
# Página 355 | nuevos=40 | total=14200
# Página 356 | nuevos=40 | total=14240
# Página 357 | nuevos=40 | total=14280
# Página 358 | nuevos=40 | total=14320
# Página 359 | nuevos=40 | total=14360
# Página 360 | nuevos=40 | total=14400
# Página 361 | nuevos=40 | total=14440
# Página 362 | nuevos=40 | total=14480
# Página 363 | nuevos=40 | total=14520
# Página 364 | nuevos=40 | total=14560
# Página 365 | nuevos=40 | total=14600
# Página 366 | nuevos=40 | total=14640
# Página 367 | nuevos=40 | total=14680
# Página 368 | nuevos=40 | total=14720
# Página 369 | nuevos=40 | total=14760
# Página 370 | nuevos=40 | total=14800
# Página 371 | nuevos=40 | total=14840
# Página 372 | nuevos=40 | total=14880
# Página 373 | nuevos=40 | total=14920
# Página 374 | nuevos=40 | total=14960
# Página 375 | nuevos=40 | total=15000
# Guardado parcial -> rawg_games_raw.csv
# Página 376 | nuevos=40 | total=15040
# Página 377 | nuevos=40 | total=15080
# Página 378 | nuevos=40 | total=15120
# Página 379 | nuevos=40 | total=15160
# Página 380 | nuevos=40 | total=15200
# Página 381 | nuevos=40 | total=15240
# Página 382 | nuevos=40 | total=15280
# Página 383 | nuevos=40 | total=15320
# Página 384 | nuevos=40 | total=15360
# Página 385 | nuevos=40 | total=15400
# Página 386 | nuevos=40 | total=15440
# Página 387 | nuevos=40 | total=15480
# Página 388 | nuevos=40 | total=15520
# Página 389 | nuevos=40 | total=15560
# Página 390 | nuevos=40 | total=15600
# Página 391 | nuevos=40 | total=15640
# Página 392 | nuevos=40 | total=15680
# Página 393 | nuevos=40 | total=15720
# Página 394 | nuevos=40 | total=15760
# Página 395 | nuevos=40 | total=15800
# Página 396 | nuevos=40 | total=15840
# Página 397 | nuevos=40 | total=15880
# Página 398 | nuevos=40 | total=15920
# Página 399 | nuevos=40 | total=15960
# Página 400 | nuevos=40 | total=16000
# Guardado parcial -> rawg_games_raw.csv
# Página 401 | nuevos=40 | total=16040
# Página 402 | nuevos=40 | total=16080
# Página 403 | nuevos=40 | total=16120
# Página 404 | nuevos=40 | total=16160
# Página 405 | nuevos=40 | total=16200
# Página 406 | nuevos=40 | total=16240
# Página 407 | nuevos=40 | total=16280
# Página 408 | nuevos=40 | total=16320
# Página 409 | nuevos=40 | total=16360
# Página 410 | nuevos=40 | total=16400
# Página 411 | nuevos=40 | total=16440
# Página 412 | nuevos=40 | total=16480
# Página 413 | nuevos=40 | total=16520
# Página 414 | nuevos=40 | total=16560
# Página 415 | nuevos=40 | total=16600
# Página 416 | nuevos=40 | total=16640
# Página 417 | nuevos=40 | total=16680
# Página 418 | nuevos=40 | total=16720
# Página 419 | nuevos=40 | total=16760
# Página 420 | nuevos=40 | total=16800
# Página 421 | nuevos=40 | total=16840
# Página 422 | nuevos=40 | total=16880
# Página 423 | nuevos=40 | total=16920
# Página 424 | nuevos=40 | total=16960
# Página 425 | nuevos=40 | total=17000
# Guardado parcial -> rawg_games_raw.csv
# Descarga cruda completa: 17000 filas -> rawg_games_raw.csv
# Limpio listo: 17000 filas -> rawg_games_clean.csv

# %%
print("RAWG cols:", df_rawg.columns.tolist())
print(df_rawg[["name","platforms_names","genres_names","stores_names"]].head(3))
print(df_rawg[["platforms_names","genres_names","stores_names"]].isna().mean() * 100)
# Out:
# RAWG cols: ['id', 'slug', 'name', 'released', 'rating', 'ratings_count', 'metacritic', 'playtime', 'added', 'suggestions_count', 'updated', 'platforms_names', 'genres_names', 'stores_names', 'background_image', 'esrb_rating.name']
#                        name  \
# 0        Grand Theft Auto V
# 1  The Witcher 3: Wild Hunt
# 2                  Portal 2
#
#                                      platforms_names     genres_names  \
# 0  PC, PlayStation 5, Xbox Series S/X, PlayStatio...           Action
# 1  PlayStation 5, Xbox Series S/X, macOS, PlaySta...      Action, RPG
# 2  PlayStation 3, PC, Xbox 360, Linux, macOS, Xbo...  Shooter, Puzzle
#
#                                         stores_names
# 0  Steam, PlayStation Store, Epic Games, Xbox 360...
# 1  GOG, PlayStation Store, Steam, Xbox Store, Nin...
# 2  Xbox Store, Steam, PlayStation Store, Xbox 360...
# platforms_names    0.0
# genres_names       0.0
# stores_names       0.0
# dtype: float64

# %%
from rapidfuzz import process, fuzz
import pandas as pd
import re, unicodedata

# --- Función para normalizar nombres ---
def normalize_name(s: str) -> str | None:
    if pd.isna(s): 
        return None
    # quitar acentos/tildes
    s = unicodedata.normalize("NFKD", str(s)).encode("ascii", "ignore").decode("ascii")
    # minúsculas
    s = s.lower()
    # eliminar texto entre paréntesis
    s = re.sub(r"\s*\(.*?\)", "", s)
    # eliminar palabras comunes irrelevantes
    s = re.sub(r"\b(edition|remastered|hd|ultimate|complete|definitive|remake|collection)\b", "", s)
    # quitar caracteres no alfanuméricos
    s = re.sub(r"[^a-z0-9]+", " ", s)
    return re.sub(r"\s+", " ", s).strip()

# --- Crear columnas normalizadas ---
df_kaggle["name_norm"] = df_kaggle["Name"].apply(normalize_name)
df_rawg["name_norm"]   = df_rawg["name"].apply(normalize_name)

# --- Matching usando la versión normalizada ---
rawg_names = df_rawg["name_norm"].tolist()
matches = []

for i, name in enumerate(df_kaggle["name_norm"]):
    match, score, idx = process.extractOne(name, rawg_names, scorer=fuzz.token_sort_ratio)

    kaggle_row = df_kaggle.iloc[i].to_dict()
    rawg_row   = df_rawg.iloc[idx].to_dict()

    combined = {**kaggle_row, **rawg_row, "match_score": score}
    matches.append(combined)

# Crear DataFrame final
df_matches = pd.DataFrame(matches)

# %%
# Guardar CSV
df_matches.to_csv("data.csv", index=False, encoding="utf-8")
print(df_matches.columns.tolist())
# Out:
# ['Rank', 'Name', 'Platform', 'Genre', 'Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'id', 'slug', 'released', 'rating', 'ratings_count', 'metacritic', 'playtime', 'added', 'suggestions_count', 'updated', 'platforms_names', 'genres_names', 'stores_names', 'background_image', 'esrb_rating.name', 'match_score']

# %%
df = pd.read_csv("data.csv")

# %% [markdown]
# # Exploración de Datos

# %% [markdown]
# ## Completitud

# %%
#Completitud

df.isnull().sum()

print ( df.isnull().sum()/len(df)*100)
# Out:
# Rank                  0.000000
# Name                  0.000000
# Platform              0.000000
# Genre                 0.000000
# Publisher             0.349440
# NA_Sales              0.000000
# EU_Sales              0.000000
# JP_Sales              0.000000
# Other_Sales           0.000000
# Global_Sales          0.000000
# id                    0.000000
# slug                  0.000000
# released              1.608628
# rating                0.000000
# ratings_count         0.000000
# metacritic           54.289673
# playtime              0.000000
# added                 0.000000
# suggestions_count     0.000000
# updated               0.000000
# platforms_names       0.000000
# genres_names          1.331486
# stores_names          9.230028
# background_image      0.234968
# esrb_rating.name     45.372936
# match_score           0.000000
# dtype: float64

# %% [markdown]
# Eliminar las columnas metacritic ya que más del 50% de los datos estan faltando por ende si se llegará a imputar el promedio o la media se generaría un sesgo sobre estos. Asimismo, se decide eliminar esrb_rating.name. Para el resto de faltantes se dicide eliminar las filas que no tengan algun dato, ya que la cantidad es mínima.

# %%
df.shape
# Out:
# (16598, 26)

# %% [markdown]
# ## Unicidad

# %%
#Unicidad
# 1) Duplicados exactos de filas completas
dup_mask_all = df.duplicated(keep=False)
df.loc[dup_mask_all].head()
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales, id, slug, released, rating, ratings_count, metacritic, playtime, added, suggestions_count, updated, platforms_names, genres_names, stores_names, background_image, esrb_rating.name, match_score]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# No hay duplicados por ende no es necesario eliminar ninguna fila.

# %%
print(df.dtypes)
# Out:
# Rank                   int64
# Name                  object
# Platform              object
# Genre                 object
# Publisher             object
# NA_Sales             float64
# EU_Sales             float64
# JP_Sales             float64
# Other_Sales          float64
# Global_Sales         float64
# id                     int64
# slug                  object
# released              object
# rating               float64
# ratings_count          int64
# metacritic           float64
# playtime               int64
# added                  int64
# suggestions_count      int64
# updated               object
# platforms_names       object
# genres_names          object
# stores_names          object
# background_image      object
# esrb_rating.name      object
# match_score          float64
# dtype: object

# %% [markdown]
# ## Consistencia

# %%
# ================================
# Consistency checks (SIN corregir ni modificar el dataset)
# ================================
import pandas as pd
from datetime import datetime, timezone

# Cargar (ajusta ruta si ya tienes df en memoria)
df = pd.read_csv("data.csv")

# ----------------------------
# 1) FECHAS: released & updated
# ----------------------------
today = pd.Timestamp(datetime.now(tz=timezone.utc).date())

released_dt = pd.to_datetime(df.get("released"), errors="coerce", utc=True)
updated_dt  = pd.to_datetime(df.get("updated"),  errors="coerce", utc=True)

mask_released_invalid   = released_dt.isna() & df.get("released").notna()
mask_released_too_old   = released_dt.dt.year.lt(1970)    # < 1970
mask_released_in_future = released_dt.dt.date.gt(today.date())
mask_updated_before_rel = (updated_dt < released_dt) & updated_dt.notna() & released_dt.notna()

print("=== FECHAS ===")
print("released inválida  :", int(mask_released_invalid.sum()))
print("released < 1970    :", int(mask_released_too_old.sum()))
print("released en futuro :", int(mask_released_in_future.sum()))
print("updated < released :", int(mask_updated_before_rel.sum()))
print(df.loc[
    mask_released_invalid | mask_released_too_old | mask_released_in_future | mask_updated_before_rel,
    [c for c in ["Name","released","updated"] if c in df.columns]
].head(10), "\n")

# -----------------------------------------------
# 2) VENTAS: NA + EU + JP + Other ≈ Global_Sales
# -----------------------------------------------
sales_cols = ["NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales"]
if all(c in df.columns for c in sales_cols):
    TOL = 0.01  # 0.01 millones ≈ 10k unidades
    reg_sum = (
        df["NA_Sales"].fillna(0) + df["EU_Sales"].fillna(0) +
        df["JP_Sales"].fillna(0) + df["Other_Sales"].fillna(0)
    )
    diff = (reg_sum - df["Global_Sales"].fillna(0)).abs()
    mask_incoh = diff > TOL

    print("=== VENTAS ===")
    print(f"Inconsistencias (> {TOL}): {int(mask_incoh.sum())} de {len(df)} ({mask_incoh.mean()*100:.2f}%)")
    print(df.loc[mask_incoh, ["Name","Platform"] + sales_cols].assign(_sales_diff=diff[mask_incoh]).head(10), "\n")

# ---------------------------------------------------------
# 3) PLATAFORMAS: Platform (Kaggle) vs platforms_names (RAWG)
# ---------------------------------------------------------
PLAT_MAP = {
    "PS":"PlayStation","PS2":"PlayStation 2","PS3":"PlayStation 3","PS4":"PlayStation 4","PS5":"PlayStation 5",
    "X360":"Xbox 360","XB":"Xbox","XOne":"Xbox One","XS":"Xbox Series S/X",
    "Wii":"Wii","WiiU":"Wii U","NS":"Nintendo Switch","3DS":"Nintendo 3DS","DS":"Nintendo DS",
    "GB":"Game Boy","GBA":"Game Boy Advance","GC":"GameCube","N64":"Nintendo 64",
    "PC":"PC","MAC":"macOS","SNES":"SNES","NES":"NES","PSP":"PSP","PSV":"PS Vita"
}

if "Platform" in df.columns and "platforms_names" in df.columns:
    plat_expected = df["Platform"].astype(str).map(lambda x: PLAT_MAP.get(x, x))
    platforms_txt = df["platforms_names"].astype(str)

    def contains_platform(expected, txt):
        if pd.isna(expected) or not isinstance(txt, str): 
            return pd.NA
        return expected in [p.strip() for p in txt.split(",")]

    platform_match = [contains_platform(e, t) for e, t in zip(plat_expected, platforms_txt)]
    platform_match = pd.Series(platform_match, index=df.index)

    pct_plat = platform_match.mean()*100 if platform_match.notna().any() else 0.0
    print("=== PLATAFORMAS ===")
    print(f"Match Platform ∈ platforms_names: {pct_plat:.2f}%")
    print(df.loc[platform_match==False, ["Name","Platform"]].assign(
        plat_expected=plat_expected[platform_match==False],
        platforms_names=platforms_txt[platform_match==False]
    ).head(10), "\n")

# -------------------------------------------------
# 4) GÉNERO: Genre (Kaggle) ∈ genres_names (RAWG)
# -------------------------------------------------
if "Genre" in df.columns and "genres_names" in df.columns:
    genre_k = df["Genre"].astype(str)
    genres_rawg = df["genres_names"].astype(str)

    def genre_in(gk, gr):
        if gk.lower() == "nan" or gr.lower() == "nan":
            return pd.NA
        return any(gk.strip().lower() == x.strip().lower() for x in gr.split(","))

    genre_match = [genre_in(gk, gr) for gk, gr in zip(genre_k, genres_rawg)]
    genre_match = pd.Series(genre_match, index=df.index)

    pct_g = genre_match.mean()*100 if genre_match.notna().any() else 0.0
    print("=== GÉNERO ===")
    print(f"Genre contenido en genres_names: {pct_g:.2f}%")
    print(df.loc[genre_match==False, ["Name","Genre","genres_names"]].head(10))
# Out:
# === FECHAS ===
# released inválida  : 0
# released < 1970    : 0
# released en futuro : 3
# updated < released : 4
#                 Name    released              updated
# 6055       WWII Aces  2025-09-25  2025-09-20T01:00:52
# 11123    Crimson Sea  2026-03-31  2025-09-23T20:17:33
# 12019  Crimson Sea 2  2026-03-31  2025-09-23T20:17:33
# 14188  Crimson Tears  2026-03-31  2025-09-23T20:17:33
#
# === VENTAS ===
# Inconsistencias (> 0.01): 2625 de 16598 (15.82%)
#                            Name Platform  NA_Sales  EU_Sales  JP_Sales  \
# 2                Mario Kart Wii      Wii     15.85     12.88      3.79
# 4      Pokemon Red/Pokemon Blue       GB     11.27      8.89     10.22
# 7                      Wii Play      Wii     14.03      9.20      2.93
# 8     New Super Mario Bros. Wii      Wii     14.59      7.06      4.70
# 10                   Nintendogs       DS      9.07     11.00      1.93
# 12  Pokemon Gold/Pokemon Silver       GB      9.00      6.18      7.20
# 18            Super Mario World     SNES     12.78      3.75      3.54
# 28       Gran Turismo 3: A-Spec      PS2      6.85      5.09      1.87
# 34   Call of Duty: Black Ops II      PS3      4.99      5.88      0.65
# 35   Call of Duty: Black Ops II     X360      8.25      4.30      0.07
#
#     Other_Sales  Global_Sales  _sales_diff
# 2          3.31         35.82         0.01
# 4          1.00         31.37         0.01
# 7          2.85         29.02         0.01
# 8          2.26         28.62         0.01
# 10         2.75         24.76         0.01
# 12         0.71         23.10         0.01
# 18         0.55         20.61         0.01
# 28         1.16         14.98         0.01
# 34         2.52         14.03         0.01
# 35         1.12         13.73         0.01
#
# === PLATAFORMAS ===
# Match Platform ∈ platforms_names: 33.62%
#                                              Name Platform plat_expected  \
# 10                                     Nintendogs       DS   Nintendo DS
# 15                             Kinect Adventures!     X360      Xbox 360
# 19   Brain Age: Train Your Brain in Minutes a Day       DS   Nintendo DS
# 27    Brain Age 2: More Training in Minutes a Day       DS   Nintendo DS
# 59                                 Super Mario 64       DS   Nintendo DS
# 66                              Final Fantasy VII       PS   PlayStation
# 89                                        Pac-Man     2600          2600
# 97            Super Smash Bros. for Wii U and 3DS      3DS  Nintendo 3DS
# 117                                 Zumba Fitness      Wii           Wii
# 122                             Big Brain Academy       DS   Nintendo DS
#
#                                        platforms_names
# 10                                               Wii U
# 15                                                  PC
# 19                                    macOS, PC, Linux
# 27                                                  PC
# 59                                         Nintendo 64
# 66                    PC, PlayStation 5, PlayStation 4
# 89   Commodore / Amiga, Game Boy Color, Atari 5200,...
# 97                                               Wii U
# 117                                           Xbox One
# 122                                Nintendo Switch, PC
#
# === GÉNERO ===
# Genre contenido en genres_names: 45.08%
#                            Name         Genre                   genres_names
# 1             Super Mario Bros.      Platform  Action, Adventure, Platformer
# 4      Pokemon Red/Pokemon Blue  Role-Playing         Action, Adventure, RPG
# 6         New Super Mario Bros.      Platform     Action, Arcade, Platformer
# 7                      Wii Play          Misc                         Family
# 8     New Super Mario Bros. Wii      Platform                     Platformer
# 9                     Duck Hunt       Shooter                         Sports
# 10                   Nintendogs    Simulation                         Family
# 12  Pokemon Gold/Pokemon Silver  Role-Playing                            RPG
# 15           Kinect Adventures!          Misc       Action, Adventure, Indie
# 18            Super Mario World      Platform             Arcade, Platformer

# %% [markdown]
# **Fechas**
# - **Eliminar** registros con `released` en el futuro.
# - **Eliminar** registros donde `updated < released`.
# - Mantener únicamente juegos con fechas válidas y consistentes para análisis históricos.
#
# **Ventas**
# - **Recalcular `Global_Sales`** como:  Global_Sales_clean = NA_Sales + EU_Sales + JP_Sales + Other_Sales
# - Conservar la columna original (`Global_Sales`) solo como referencia.
# - Utilizar siempre `Global_Sales_clean` en los análisis para garantizar coherencia.
#
# **Plataformas**
# - Usar **`platforms_names` de RAWG** como columna oficial de plataformas.
# - Conservar `Platform` de Kaggle únicamente como columna auxiliar para validaciones.
# - *(Opcional)* Crear un flag `platform_match` que indique coincidencias o discrepancias, pero usar solo RAWG en los análisis finales.
#
# **Género**
# - Usar **`Genre` de Kaggle** como categoría principal (es más simple y representativa).
# - Mantener `genres_names` de RAWG como columna secundaria para enriquecer análisis avanzados (ej. juegos multigénero).

# %% [markdown]
# ## Validez

# %% [markdown]
# 1. Ventas
# - Los juegos más vendidos históricamente alcanzan entre **40 y 82 millones de copias** (*Wii Sports*, *Super Mario Bros.*).
# - **Verificaciones:**
#   - `Global_Sales` ≤ 100M (umbral razonable).
#   - Ninguna venta regional (`NA_Sales`, `EU_Sales`, `JP_Sales`, `Other_Sales`) negativa.
#   - `Global_Sales` ≥ máximo de las ventas regionales.
#
# 2. Fechas
# - Primeros videojuegos comerciales desde **1970**.
# - RAWG incluye fechas futuras, pero deben corresponder a lanzamientos reales o próximos.
# - **Verificaciones:**
#   - `released` ≥ 1970.
#   - `released` ≤ fecha actual (salvo *coming soon*).
#   - `updated` ≥ `released` (última actualización posterior al lanzamiento).
#
# 3. Ratings
# - `rating` en RAWG: escala **0–5**.
# - `metacritic`: escala **0–100**.
# - **Verificaciones:**
#   - Ningún valor fuera de rango.
#   - Juegos con `ratings_count` alto pero `rating = 0` → sospechosos.
#
#
# 4. Plataformas
# - Plataformas deben corresponder a consolas reales: `NES`, `SNES`, `Wii`, `PS2`, `Xbox 360`, `PC`, etc.
# - **Verificaciones:**
#   - `Platform` de Kaggle debe estar en un diccionario de abreviaturas válidas.
#   - `platforms_names` de RAWG no debe estar vacío (sobre todo en juegos modernos).
#   - Normalización de equivalencias (`PS` = `PlayStation`).
#
#
# 5. Géneros
# - Géneros comunes: *Action, Sports, RPG, Racing, Shooter, Adventure, Fighting, Platformer*.
# - **Verificaciones:**
#   - `Genre` de Kaggle dentro del catálogo esperado.
#   - Evitar valores ambiguos como `"Misc"` o `"N/A"`.
#   - Validación cruzada: `Genre` de Kaggle ∈ `genres_names` de RAWG.
#
#
# 6. Publisher / Developer
# - Publishers legítimos: *Nintendo, EA, Ubisoft, Activision, Square Enix*.
# - **Verificaciones:**
#   - Evitar valores `"Unknown"`, nulos o inconsistentes.
#   - Unificar duplicados (*EA* vs *Electronic Arts*).
#   - Revisar outliers de frecuencia (publishers que aparecen una sola vez).
#
#
# ## 📌 Conclusión
# La validez contextual asegura que los datos:
# - **Respetan rangos realistas** (ventas, ratings, fechas).
# - **Mantienen coherencia histórica** (fechas plausibles).
# - **Usan catálogos válidos** (plataformas, géneros, publishers).
#
# Esto garantiza que los análisis y el modelo dimensional se basen en información confiable.

# %%
from IPython.display import display, HTML
import pandas as pd

# (Opcional) Ajustes de visualización
pd.set_option("display.max_rows", 200)      # aumenta si necesitas ver más filas
pd.set_option("display.max_columns", 200)   # aumenta si necesitas ver más columnas
pd.set_option("display.float_format", lambda x: f"{x:,.4f}")  # formato numérico

def mostrar_resumen(res):
    # 1) Info básica
    print("▶ Info básica")
    display(res["basic_info"])

    # 2) Perfil de columnas
    print("\n▶ Perfil de columnas")
    colprof = res["column_profile"]
    display(colprof if colprof.shape[0] <= 60 else colprof.head(60))

    # 3) Estadísticos numéricos
    print("\n▶ Estadísticos numéricos")
    numdesc = res["numeric_describe"]
    if not numdesc.empty:
        display(numdesc if numdesc.shape[0] <= 60 else numdesc.head(60))
    else:
        print("(No hay columnas numéricas)")

    # 4) Matriz de correlación (si aplica)
    print("\n▶ Matriz de correlación (numérica)")
    corr = res["correlation"]
    if isinstance(corr, pd.DataFrame) and not corr.empty:
        # (Opcional) Estilo de calor para leer mejor
        display(corr.style.background_gradient())
    else:
        print("(No hay suficientes columnas numéricas para correlación)")

    # 5) Top-10 categorías por columna no numérica
    print("\n▶ Top-10 categorías por columna no numérica")
    topk = res["categorical_top10"]
    if isinstance(topk, pd.DataFrame) and not topk.empty:
        display(topk if topk.shape[0] <= 100 else topk.head(100))
    else:
        print("(No hay columnas categóricas o están vacías)")

    # 6) Filas duplicadas
    print("\n▶ Filas duplicadas")
    display(res["duplicates"])

# Mostrar en la celda:
mostrar_resumen(resumen)
# Out:
# ▶ Info básica
#       dataset   rows  columns  memory_MB
# 0  VideoGames  16598       26    16.2760
# ▶ Perfil de columnas
#                column    dtype     nunique    missing  missing_%  \
# 0                Rank    int64         NaN        NaN        NaN
# 1                Name   object         NaN        NaN        NaN
# 2            Platform   object         NaN        NaN        NaN
# 3               Genre   object         NaN        NaN        NaN
# 4           Publisher   object         NaN        NaN        NaN
# 5            NA_Sales  float64         NaN        NaN        NaN
# 6            EU_Sales  float64         NaN        NaN        NaN
# 7            JP_Sales  float64         NaN        NaN        NaN
# 8         Other_Sales  float64         NaN        NaN        NaN
# 9        Global_Sales  float64         NaN        NaN        NaN
# 10                 id    int64         NaN        NaN        NaN
# 11               slug   object         NaN        NaN        NaN
# 12           released   object         NaN        NaN        NaN
# 13             rating  float64         NaN        NaN        NaN
# 14      ratings_count    int64         NaN        NaN        NaN
# 15         metacritic  float64         NaN        NaN        NaN
# 16           playtime    int64         NaN        NaN        NaN
# 17              added    int64         NaN        NaN        NaN
# 18  suggestions_count    int64         NaN        NaN        NaN
# 19            updated   object         NaN        NaN        NaN
# 20    platforms_names   object         NaN        NaN        NaN
# 21       genres_names   object         NaN        NaN        NaN
# 22       stores_names   object         NaN        NaN        NaN
# 23   background_image   object         NaN        NaN        NaN
# 24   esrb_rating.name   object         NaN        NaN        NaN
# 25        match_score  float64         NaN        NaN        NaN
# 26                NaN      NaN 16,598.0000     0.0000     0.0000
# 27                NaN      NaN 11,493.0000     0.0000     0.0000
# 28                NaN      NaN     31.0000     0.0000     0.0000
# 29                NaN      NaN     12.0000     0.0000     0.0000
# 30                NaN      NaN    578.0000    58.0000     0.3500
# 31                NaN      NaN    409.0000     0.0000     0.0000
# 32                NaN      NaN    305.0000     0.0000     0.0000
# 33                NaN      NaN    244.0000     0.0000     0.0000
# 34                NaN      NaN    157.0000     0.0000     0.0000
# 35                NaN      NaN    623.0000     0.0000     0.0000
# 36                NaN      NaN  6,515.0000     0.0000     0.0000
# 37                NaN      NaN  6,515.0000     0.0000     0.0000
# 38                NaN      NaN  3,658.0000   267.0000     1.6100
# 39                NaN      NaN    324.0000     0.0000     0.0000
# 40                NaN      NaN    820.0000     0.0000     0.0000
# 41                NaN      NaN     72.0000 9,011.0000    54.2900
# 42                NaN      NaN     91.0000     0.0000     0.0000
# 43                NaN      NaN  1,979.0000     0.0000     0.0000
# 44                NaN      NaN    816.0000     0.0000     0.0000
# 45                NaN      NaN  6,365.0000     0.0000     0.0000
# 46                NaN      NaN  2,039.0000     0.0000     0.0000
# 47                NaN      NaN    663.0000   221.0000     1.3300
# 48                NaN      NaN    885.0000 1,532.0000     9.2300
# 49                NaN      NaN  6,503.0000    39.0000     0.2300
# 50                NaN      NaN      6.0000 7,531.0000    45.3700
# 51                NaN      NaN    678.0000     0.0000     0.0000
#
#                                              examples
# 0                                             1, 2, 3
# 1       Wii Sports, Super Mario Bros., Mario Kart Wii
# 2                                       Wii, NES, Wii
# 3                            Sports, Platform, Racing
# 4                        Nintendo, Nintendo, Nintendo
# 5                                 41.49, 29.08, 15.85
# 6                                  29.02, 3.58, 12.88
# 7                                    3.77, 6.81, 3.79
# 8                                    8.46, 0.77, 3.31
# 9                                 82.74, 40.24, 35.82
# 10                                25057, 25080, 24761
# 11       wii-sports, super-mario-bros, mario-kart-wii
# 12                 2006-11-19, 1985-09-13, 2008-04-27
# 13                                    4.21, 4.32, 4.3
# 14                                      260, 776, 306
# 15                                   76.0, 82.0, 80.0
# 16                                         55, 30, 12
# 17                                     479, 1519, 638
# 18                                      177, 133, 384
# 19  2025-09-19T16:01:12, 2025-09-10T04:00:34, 2025...
# 20  Wii, NES, Game Boy Advance, Game Boy Color, Wi...
# 21      Sports, Action, Adventure, Platformer, Racing
# 22     Nintendo Store, Nintendo Store, Nintendo Store
# 23  https://media.rawg.io/media/games/173/1739bdc5...
# 24                       Everyone, Everyone, Everyone
# 25                                100.0, 100.0, 100.0
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# ▶ Estadísticos numéricos
#                column       count        mean          std     min  \
# 0                Rank 16,598.0000  8,300.6053   4,791.8539  1.0000
# 1            NA_Sales 16,598.0000      0.2647       0.8167  0.0000
# 2            EU_Sales 16,598.0000      0.1467       0.5054  0.0000
# 3            JP_Sales 16,598.0000      0.0778       0.3093  0.0000
# 4         Other_Sales 16,598.0000      0.0481       0.1886  0.0000
# 5        Global_Sales 16,598.0000      0.5374       1.5550  0.0100
# 6                  id 16,598.0000 83,528.7697 173,947.4414  1.0000
# 7              rating 16,598.0000      2.9712       1.3516  0.0000
# 8       ratings_count 16,598.0000    175.0234     448.5983  0.0000
# 9          metacritic  7,587.0000     74.3390      11.4865 21.0000
# 10           playtime 16,598.0000      4.4578      14.1733  0.0000
# 11              added 16,598.0000  1,000.3390   1,944.8279 85.0000
# 12  suggestions_count 16,598.0000    399.1334     186.0993  0.0000
# 13        match_score 16,598.0000     76.6428      17.5121 37.5691
#
#            25%         50%         75%            max         IQR  \
# 0   4,151.2500  8,300.5000 12,449.7500    16,600.0000  8,298.5000
# 1       0.0000      0.0800      0.2400        41.4900      0.2400
# 2       0.0000      0.0200      0.1100        29.0200      0.1100
# 3       0.0000      0.0000      0.0400        10.2200      0.0400
# 4       0.0000      0.0100      0.0400        10.5700      0.0400
# 5       0.0600      0.1700      0.4700        82.7400      0.4100
# 6  10,241.0000 21,054.0000 49,057.0000 1,003,457.0000 38,816.0000
# 7       2.6500      3.4400      3.9000         4.7500      1.2500
# 8      12.0000     40.0000    125.0000     7,215.0000    113.0000
# 9      67.0000     76.0000     82.0000        99.0000     15.0000
# 10      1.0000      2.0000      4.0000       900.0000      3.0000
# 11    146.0000    301.0000    850.0000    22,239.0000    704.0000
# 12    261.0000    392.0000    526.0000     1,736.0000    265.0000
# 13     62.0690     72.0000    100.0000       100.0000     37.9310
#
#     outliers_IQR    skew   kurtosis  zero_%
# 0              0  0.0001    -1.1999  0.0000
# 1           1681 18.7996   649.1303 27.1100
# 2           2081 18.8755   756.0278 34.5200
# 3           2425 11.2065   194.2340 62.9900
# 4           1665 24.2339 1,025.3481 39.0200
# 5           1893 17.4006   603.9323  0.0000
# 6           2221  3.0305     9.0849  0.0000
# 7           2296 -1.2895     0.4714 13.8300
# 8           2156  6.1983    56.5672  2.2800
# 9            154 -0.8273     0.9491  0.0000
# 10          1511 22.7177 1,067.7722 21.5800
# 11          2223  4.3531    25.2553  0.0000
# 12           157  0.5644     1.3691  0.2100
# 13             0  0.2103    -1.4153  0.0000
# ▶ Matriz de correlación (numérica)
# <style type="text/css">
# #T_fbd56_row0_col0, #T_fbd56_row1_col1, #T_fbd56_row2_col2, #T_fbd56_row3_col3, #T_fbd56_row4_col4, #T_fbd56_row5_col5, #T_fbd56_row6_col6, #T_fbd56_row7_col7, #T_fbd56_row8_col8, #T_fbd56_row9_col9, #T_fbd56_row10_col10, #T_fbd56_row11_col11, #T_fbd56_row12_col12, #T_fbd56_row13_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_fbd56_row0_col1, #T_fbd56_row0_col2, #T_fbd56_row0_col3, #T_fbd56_row0_col4, #T_fbd56_row0_col5, #T_fbd56_row0_col7, #T_fbd56_row0_col8, #T_fbd56_row0_col9, #T_fbd56_row0_col10, #T_fbd56_row0_col13, #T_fbd56_row5_col0, #T_fbd56_row6_col11, #T_fbd56_row6_col12, #T_fbd56_row13_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_fbd56_row0_col6, #T_fbd56_row10_col7 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_fbd56_row0_col11 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_fbd56_row0_col12, #T_fbd56_row3_col12 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_fbd56_row1_col0, #T_fbd56_row12_col6 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_fbd56_row1_col2 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_fbd56_row1_col3 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_fbd56_row1_col4 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_fbd56_row1_col5, #T_fbd56_row5_col1 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_fbd56_row1_col6, #T_fbd56_row5_col6 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_fbd56_row1_col7, #T_fbd56_row6_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_fbd56_row1_col8, #T_fbd56_row12_col5 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_fbd56_row1_col9, #T_fbd56_row5_col9, #T_fbd56_row6_col5, #T_fbd56_row7_col3 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_fbd56_row1_col10, #T_fbd56_row10_col12 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_fbd56_row1_col11, #T_fbd56_row2_col10, #T_fbd56_row3_col7, #T_fbd56_row3_col9, #T_fbd56_row5_col10, #T_fbd56_row6_col3, #T_fbd56_row6_col4 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_fbd56_row1_col12, #T_fbd56_row3_col8, #T_fbd56_row5_col12, #T_fbd56_row10_col6 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_fbd56_row1_col13, #T_fbd56_row2_col13, #T_fbd56_row8_col4 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_fbd56_row2_col0 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_fbd56_row2_col1 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_fbd56_row2_col3 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_fbd56_row2_col4 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_fbd56_row2_col5 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_fbd56_row2_col6, #T_fbd56_row4_col6 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_fbd56_row2_col7, #T_fbd56_row2_col9, #T_fbd56_row4_col11, #T_fbd56_row13_col3 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_fbd56_row2_col8, #T_fbd56_row4_col8 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_fbd56_row2_col11, #T_fbd56_row5_col7, #T_fbd56_row12_col0 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_fbd56_row2_col12, #T_fbd56_row7_col0 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_fbd56_row3_col0, #T_fbd56_row12_col10 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_fbd56_row3_col1 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_fbd56_row3_col2 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_fbd56_row3_col4 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_fbd56_row3_col5 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_fbd56_row3_col6, #T_fbd56_row4_col10, #T_fbd56_row7_col10, #T_fbd56_row12_col3 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_fbd56_row3_col10, #T_fbd56_row13_col9 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_fbd56_row3_col11, #T_fbd56_row9_col12 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_fbd56_row3_col13 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_fbd56_row4_col0 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_fbd56_row4_col1 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_fbd56_row4_col2 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_fbd56_row4_col3, #T_fbd56_row8_col5, #T_fbd56_row13_col1 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_fbd56_row4_col5 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_fbd56_row4_col7, #T_fbd56_row4_col9 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_fbd56_row4_col12, #T_fbd56_row11_col3 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_fbd56_row4_col13, #T_fbd56_row10_col5 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_fbd56_row5_col2 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_fbd56_row5_col3 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_fbd56_row5_col4 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_fbd56_row5_col8 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_fbd56_row5_col11 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_fbd56_row5_col13, #T_fbd56_row8_col9, #T_fbd56_row11_col13 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_fbd56_row6_col0, #T_fbd56_row12_col8, #T_fbd56_row12_col11, #T_fbd56_row13_col8 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_fbd56_row6_col2, #T_fbd56_row9_col10 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_fbd56_row6_col7, #T_fbd56_row6_col13 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_fbd56_row6_col8, #T_fbd56_row13_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_fbd56_row6_col9, #T_fbd56_row7_col6 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_fbd56_row6_col10 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_fbd56_row7_col1, #T_fbd56_row10_col1, #T_fbd56_row11_col4 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_fbd56_row7_col2, #T_fbd56_row11_col1 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_fbd56_row7_col4, #T_fbd56_row7_col11 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_fbd56_row7_col5, #T_fbd56_row11_col5 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_fbd56_row7_col8, #T_fbd56_row7_col12, #T_fbd56_row12_col7 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_fbd56_row7_col9 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_fbd56_row7_col13 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_fbd56_row8_col0 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_fbd56_row8_col1, #T_fbd56_row9_col5 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_fbd56_row8_col2 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_fbd56_row8_col3, #T_fbd56_row11_col0 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_fbd56_row8_col6 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_fbd56_row8_col7, #T_fbd56_row9_col2, #T_fbd56_row10_col2 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_fbd56_row8_col10 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_fbd56_row8_col11 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_fbd56_row8_col12, #T_fbd56_row11_col7 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_fbd56_row8_col13, #T_fbd56_row13_col5 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_fbd56_row9_col0 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_fbd56_row9_col1, #T_fbd56_row11_col2 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_fbd56_row9_col3 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_fbd56_row9_col4 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_fbd56_row9_col6, #T_fbd56_row11_col10 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_fbd56_row9_col7 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_fbd56_row9_col8 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_fbd56_row9_col11, #T_fbd56_row11_col12 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_fbd56_row9_col13, #T_fbd56_row10_col4 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_fbd56_row10_col0 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_fbd56_row10_col3 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_fbd56_row10_col8 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_fbd5
# ▶ Top-10 categorías por columna no numérica
#              column                                     value  count
# 0              Name               Need for Speed: Most Wanted     12
# 1              Name                                   FIFA 14      9
# 2              Name                  LEGO Marvel Super Heroes      9
# 3              Name                             Madden NFL 07      9
# 4              Name                               Ratatouille      9
# 5              Name                                  Terraria      8
# 6              Name   LEGO Star Wars II: The Original Trilogy      8
# 7              Name                  The LEGO Movie Videogame      8
# 8              Name                             Madden NFL 08      8
# 9              Name                                   FIFA 15      8
# 10         Platform                                        DS   2163
# 11         Platform                                       PS2   2161
# 12         Platform                                       PS3   1329
# 13         Platform                                       Wii   1325
# 14         Platform                                      X360   1265
# 15         Platform                                       PSP   1213
# 16         Platform                                        PS   1196
# 17         Platform                                        PC    960
# 18         Platform                                        XB    824
# 19         Platform                                       GBA    822
# 20            Genre                                    Action   3316
# 21            Genre                                    Sports   2346
# 22            Genre                                      Misc   1739
# 23            Genre                              Role-Playing   1488
# 24            Genre                                   Shooter   1310
# 25            Genre                                 Adventure   1286
# 26            Genre                                    Racing   1249
# 27            Genre                                  Platform    886
# 28            Genre                                Simulation    867
# 29            Genre                                  Fighting    848
# 30        Publisher                           Electronic Arts   1351
# 31        Publisher                                Activision    975
# 32        Publisher                        Namco Bandai Games    932
# 33        Publisher                                   Ubisoft    921
# 34        Publisher              Konami Digital Entertainment    832
# 35        Publisher                                       THQ    715
# 36        Publisher                                  Nintendo    703
# 37        Publisher               Sony Computer Entertainment    683
# 38        Publisher                                      Sega    639
# 39        Publisher                      Take-Two Interactive    413
# 40             slug                      tigerwoodspgatour-10     49
# 41             slug                          ncaa-football-10     42
# 42             slug                     super-mega-baseball-2     42
# 43             slug     mobile-suit-gundam-battle-operation-2     33
# 44             slug                             madden-nfl-20     31
# 45             slug                 ducati-world-championship     29
# 46             slug                               nba-live-06     29
# 47             slug                             power-link-vr     26
# 48             slug                                  singstar     26
# 49             slug                       goalie-challenge-vr     23
# 50         released                                2008-01-01     49
# 51         released                                2009-06-08     49
# 52         released                                2018-05-01     46
# 53         released                                2009-07-14     43
# 54         released                                2009-09-15     41
# 55         released                                2019-10-01     36
# 56         released                                2005-09-26     36
# 57         released                                2007-11-13     36
# 58         released                                1995-01-01     36
# 59         released                                2011-11-15     34
# 60          updated                       2023-05-07T17:49:29     49
# 61          updated                       2023-05-07T10:04:53     42
# 62          updated                       2022-08-05T07:57:31     42
# 63          updated                       2025-05-04T10:28:58     33
# 64          updated                       2023-05-24T16:32:33     31
# 65          updated                       2022-09-02T03:26:40     29
# 66          updated                       2024-12-29T07:34:57     29
# 67          updated                       2019-08-28T22:11:58     26
# 68          updated                       2024-11-07T10:18:04     26
# 69          updated                       2024-01-20T00:14:13     23
# 70  platforms_names                                        PC   3394
# 71  platforms_names                                 macOS, PC    322
# 72  platforms_names                                 PC, macOS    320
# 73  platforms_names                          macOS, PC, Linux    263
# 74  platforms_names                                  Xbox 360    238
# 75  platforms_names                          PC, macOS, Linux    189
# 76  platforms_names               PlayStation 4, Xbox One, PC    142
# 77  platforms_names                   PlayStation 3, Xbox 360    136
# 78  platforms_names                             PlayStation 3    132
# 79  platforms_names               Xbox One, PlayStation 4, PC    130
# 80     genres_names                                    Action    954
# 81     genres_names                         Action, Adventure    950
# 82     genres_names                           Action, Shooter    883
# 83     genres_names                                    Sports    817
# 84     genres_names                                       RPG    435
# 85     genres_names                                  Strategy    391
# 86     genres_names                               Action, RPG    385
# 87     genres_names                             Action, Indie    372
# 88     genres_names                                 Adventure    327
# 89     genres_names                  Action, Adventure, Indie    321
# 90     stores_names                                     Steam   4119
# 91     stores_names                            Nintendo Store    822
# 92     stores_names                         PlayStation Store    742
# 93     stores_names                            Xbox 360 Store    703
# 94     stores_names                                Steam, GOG    466
# 95     stores_names                  PlayStation Store, Steam    286
# 96     stores_names                                GOG, Steam    284
# 97     stores_names            Nintendo Store, Xbox 360 Store    240
# 98     stores_names         PlayStation Store, Xbox 360 Store    239
# 99     stores_names  PlayStation Store, Steam, Xbox 360 Store    182
# ▶ Filas duplicadas
#       dataset  duplicate_rows
# 0  VideoGames               0

# %% [markdown]
# En términos descriptivos, las variables de ventas presentan medias claramente superiores a las medianas, lo que evidencia asimetría positiva: la “tendencia central” real está mejor representada por la mediana y el IQR que por la media y la desviación estándar. Los máximos están muy alejados del rango intercuartílico (P75), confirmando la presencia de títulos con ventas extraordinarias que empujan hacia arriba los promedios; al mismo tiempo hay una alta proporción de ceros en varias regiones, lo que aumenta la dispersión y reduce la capacidad de la media para resumir el comportamiento típico. Entre numéricas se observan correlaciones fuertes entre ventas regionales y el total global (multicolinealidad esperable), mientras que en el detalle por región los outliers (según 1.5×IQR) concentran buena parte de la varianza. En conjunto: para resumir estos datos conviene reportar mediana, IQR, mínimos y máximos (además de media y desviación estándar), y acompañar con una breve nota sobre proporción de ceros y correlaciones entre ventas regionales y globales, evitando que unos pocos valores extremos distorsionen la lectura.
